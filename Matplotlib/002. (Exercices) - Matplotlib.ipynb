# %% [markdown]
# # Notebook d'exercices sur Matplotlib avec le jeu de données Iris

# %%
## Chargement des données
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Charger le jeu de données Iris
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['espèce'] = iris.target

# Traduction des noms de colonnes en français
iris_df.columns = ['longueur sépale', 'largeur sépale', 'longueur pétale', 'largeur pétale', 'espèce']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 ## Chargement des données
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.datasets import load_iris
#       5
#       6 # Charger le jeu de données Iris
#       7 iris = load_iris()
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Exercice 1 : Visualisation des relations entre les caractéristiques
# Tracer un graphique en nuage de points des valeurs de 'longueur sépale' en fonction de 'largeur sépale'.
#
# Que pouvez-vous observer sur la relation entre ces deux caractéristiques ?

# %% [markdown]
# ## Exercice 2 : Analyse des espèces
# Ajouter une couleur différente pour chaque espèce dans le graphique de l'exercice 1.
#
# Les espèces sont-elles bien séparées visuellement ?

# %% [markdown]
# ## Exercice 3 : Distribution des caractéristiques
# Créez un histogramme des valeurs de 'longueur pétale'.
#
# La distribution est-elle uniforme ou y a-t-il des pics ?

# %% [markdown]
# ## Exercice 4 : Personnalisation avancée
# Personnalisez le graphique de l'exercice 2 en ajoutant une légende, en modifiant le style des points et en ajoutant une grille.
#
# Comment ces personnalisations aident-elles à mieux comprendre les données ?

# %% [markdown]
# ## Exercice 5 : Comparaison des caractéristiques
# Créez un graphique comparant 'longueur pétale' et 'largeur pétale' pour chaque espèce.
#
# Y a-t-il une corrélation visible entre ces caractéristiques pour certaines espèces ?
